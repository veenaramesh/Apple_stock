# %%
import numpy as np
import pandas as pd

# %%
fundamentals = pd.read_csv("fundamentals.csv")

# %%
fundamentals.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  \
# 0         -1.888000e+09     4.695000e+09        53.0
# 1         -3.114000e+09     1.059200e+10        75.0
# ...

# %%
import sklearn
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
apple = pd.read_csv("HistoricalQuotes.csv")

# %%
apple.head()
# Out:
#          date    close         volume     open     high     low
# 0       11:50  175.247     11,141,417  175.120  176.095  174.80
# 1  2017/11/08  176.240  24358920.0000  174.660  176.240  174.33
# 2  2017/11/07  174.810  24332120.0000  173.910  175.250  173.60
# 3  2017/11/06  174.250  34770480.0000  172.365  174.990  171.72
# 4  2017/11/03  172.500  59332210.0000  174.000  174.260  171.12

# %%
dow = pd.read_csv("^DJI.csv")
dow.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2012-11-09  12811.169922  12890.190430  12743.389648  12815.389648
# 1  2012-11-12  12815.929688  12861.280273  12783.000000  12815.080078
# 2  2012-11-13  12808.709961  12898.250000  12748.509766  12756.179688
# 3  2012-11-14  12746.540039  12797.730469  12542.679688  12570.950195
# 4  2012-11-15  12571.099609  12600.589844  12496.559570  12542.379883
#
#       Adj Close     Volume
# 0  12815.389648  131670000
# 1  12815.080078   62360000
# 2  12756.179688  142200000
# 3  12570.950195  162180000
# 4  12542.379883  129150000

# %%
sp = pd.read_csv("^GSPC.csv")
sp.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2012-11-09  1377.550049  1391.390015  1373.030029  1379.849976
# 1  2012-11-12  1379.859985  1384.869995  1377.189941  1380.030029
# 2  2012-11-13  1380.030029  1388.810059  1371.390015  1374.530029
# 3  2012-11-14  1374.640015  1380.130005  1352.500000  1355.489990
# 4  2012-11-15  1355.410034  1360.619995  1348.050049  1353.329956
#
#      Adj Close      Volume
# 0  1379.849976  3647350000
# 1  1380.030029  2567540000
# 2  1374.530029  3455550000
# 3  1355.489990  4109510000
# 4  1353.329956  3928870000

# %%
russ = pd.read_csv("^RUT.csv")
russ.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2012-11-09  793.619995  800.719971  789.250000  795.020020  795.020020
# 1  2012-11-12  796.979980  797.729980  792.900024  793.760010  793.760010
# 2  2012-11-13  792.210022  795.969971  788.770020  789.010010  789.010010
# 3  2012-11-14  791.349976  792.099976  772.429993  773.200012  773.200012
# 4  2012-11-15  772.469971  775.080017  765.030029  769.479980  769.479980
#
#      Volume
# 0  36473500
# 1  25675400
# 2  34555500
# 3  41095100
# 4  39288700

# %%
fundamentals = pd.read_csv("fundamentals.csv")

# %%
from sklearn.ensemble import RandomForestRegressor
fundamentals['RANDOM'] = np.random.rand(len(fundamentals))*100

y = fundamentals['Earnings Per Share']
x = fundamentals.drop('Earnings Per Share', axis = 1)

# %%
forest = RandomForestRegressor(n_estimators = 100)
forest.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-26e0e6acca73> in <module>()
#       1 forest = RandomForestRegressor(n_estimators = 100)
# ----> 2 forest.fit(x,y)
#
# C:\Users\veena\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if issparse(X):
#
# C:\Users\veena\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     380                                       force_all_finite)
#     381     else:
# ...

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
fundamentals = pd.read_csv("fundamentals.csv", index_col = "Period Ending",  date_parser = dateparse)
fundamentals.index
# Out:
# DatetimeIndex(['2012-12-31', '2013-12-31', '2014-12-31', '2015-12-31',
#                '2012-12-29', '2013-12-28', '2015-01-03', '2016-01-02',
#                '2013-09-28', '2014-09-27',
#                ...
#                '2014-12-31', '2015-12-31', '2012-12-31', '2013-12-31',
#                '2014-12-31', '2015-12-31', '2013-12-31', '2014-12-31',
#                '2015-12-31', '2016-12-31'],
#               dtype='datetime64[ns]', name='Period Ending', length=1781, freq=None)

# %%
import matplotlib.pylab as plt
plt.plot(fundamentals)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1a9fa6232c5e> in <module>()
#       1 import matplotlib.pylab as plt
# ----> 2 plt.plot(fundamentals)
#
# C:\Users\veena\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# C:\Users\veena\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# ...
